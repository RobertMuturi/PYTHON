# %% [markdown]
# ## **MACHINE LEARNING**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Supervised Machine Learning :
# The Supervised Machine Learning algorithms are classified into two types :
# 1. Classification
# 2. Regression
# - Classification :
# Classification is defined as the process of predicting a class or category from observed values or given data points. The categorized output can have forms such as “Black” or “White” or “spam” or “no-spam”.
# We have two types of learners in respective classification problems:
# 1. Lazy Learners :
# As the name suggests, such kind of learners waits for the testing data to be appeared after storing the training data. Classification is done only after getting the testing data. They spend less time on training but more time on predicting. Examples of lazy learners are Knearest neighbor and case-based reasoning.
# 2. Eager Learners :
# As opposite to lazy learners, eager learners construct a classification model without waiting for the testing data to be appeared after storing the training data. They spend more time on training but less time on predicting. Examples of eager learners are Decision Trees, Naïve Bayes, and Artificial Neural Networks (ANN).
# Regression :
# Regression-based tasks are to predict output labels or responses which are continuous numeric values, for the given input data. The output will be based on what the model has learned in the training phase. Basically, regression models use the input data features (independent variables) and their corresponding continuous numeric output values (dependent or outcome variables) to learn the specific association between inputs and corresponding outputs.
# Regression models are of two types :
#
# 1. Simple regression model: This is the most basic regression model in which predictions are formed from a single, univariate feature of the data.
# 2. Multiple regression model: As the name implies, in this regression model the predictions are formed from multiple features of the data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is specially for people who are interested in Machine Learning and curious to know more about Data Scientist job.
#
# ✅ Linear Regression - Lead Conversion Propensity model, Unemployment rate analysis (research work)
#
# ✅ Logistic Regression - Lead Conversion Propensity model
#
# ✅ Decision Trees - Lead Conversion Propensity model, Analysis of Investment in Cryptos
#
# ✅ Random Forest - Analysis of Investment in Cryptos (research work)
#
# ✅ Support Vector Machine - Unemployment rate Analysis, Analysis of Investment in Cryptos

# %% [markdown]
# Machine Learning (ML) is that field of computer science with the help of which computer systems can provide sense to data in much the same way
# as human beings do. Machine Learning is a type of artificial intelligence that extract patterns out of raw data by using an algorithm or method. The main focus of ML
# is to allow computer systems learn from experience without being explicitly programmed or human intervention.

# %% [markdown]
# ### **Importance of machine learning**
# The question we are trying to answer is what is the need to make machine learn? The most suitable reason for doing this is, “to make decisions, based on data, with efficiency and scale”. There can be several circumstances where we need machines to take data-driven decisions with efficiency and at a huge scale. The followings are some of such circumstances where making machines learn would be more effective −
#
# - Lack of human expertise
# - Dynamic scenarios-There are some scenarios which are dynamic in nature i.e. they keep changing over time.
# - Difficulty in translating expertise into computational tasks-There can be various domains in which humans have their expertise,; however, they are unable to translate this expertise into computational tasks. In such circumstances we want machine learning. The examples can be the domains of speech recognition, cognitive tasks etc

# %% [markdown]
# ### Machine Learning Model

# %% [markdown]
#  professor Mitchell gave the following definition of ML
#     “A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P,
#     if its performance at tasks in T, as measured by P, improves with experience E.” These are also the main components of
#     any learning algorithm, namely Task(T), Performance(P) and experience (E). In this context, we can simplify this definition
#     as −
#
# ML is a field of AI consisting of learning algorithms that −
#
# 1. ### **Improve their performance**
# (P)-An ML algorithm is supposed to perform task and gain experience with the passage of time. The measure which tells
# whether ML algorithm is performing as per expectation or not is its performance (P). P is basically a quantitative metric    that tells how a model is performing the task, T, using its experience, E.
# 2. ### **At executing some task (T)**
# From the perspective of problem, we may define the task T as the real-world problem to be solved
# 3. ### **Over time with experience (E)**
# it is the knowledge gained from data points provided to the algorithm or model. Once provided with the dataset, the model will run iteratively and will learn some inherent pattern. The learning thus  acquired is called experience(E)

# %% [markdown]
# **Applications of machine learning**

# %% [markdown]
# - Speech recognition
#
# - Customer segmentation
#
# - Object recognition
#
# - Fraud detection
#
# - Fraud prevention
#
# - Recommendation of products to customer in online shopping.
#
# - Emotion analysis
#
# - Sentiment analysis
#
# - Error detection and prevention
#
# - Weather forecasting and prediction
#
# - Stock market analysis and forecasting
#
# - Speech synthesis

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# These are some resources to help in understanding the basics and theories of things before diving into code. I highly encourage going through them before going through the notebook.
#
# - https://www.youtube.com/watch?v=WNvOtwP_yf4%2F%3Futm_source%3Dnewsletter&utm_medium=email&utm_campaign=2019-february-gcp-newsletter-en
# - https://medium.com/swlh/linear-regression-lab-for-dummies-in-python-a16cf2b93957
# - https://towardsdatascience.com/laymans-introduction-to-linear-regression-8b334a3dab09#:~:text=Linear%20regression%20attempts%20to%20model,variable%20(e.g.%20your%20expenses).

# %% [markdown]
# Your neighbor is a real estate agent and wants some help predicting housing prices for regions in the USA. It would be great if you could somehow create a model for her that allows her to put in a few features of a house and returns back an estimate of what the house would sell for.
#
# She has asked you if you could help her out with your new data science skills. You say yes, and decide that Linear Regression might be a good path to solve this problem!
#
# Your neighbor then gives you some information about a bunch of houses in regions of the United States,it is all in the data set: USA_Housing.csv.
#
# The data contains the following columns:
#
# * 'Avg. Area Income': Avg. Income of residents of the city house is located in.
# * 'Avg. Area House Age': Avg Age of Houses in same city
# * 'Avg. Area Number of Rooms': Avg Number of Rooms for Houses in same city
# * 'Avg. Area Number of Bedrooms': Avg Number of Bedrooms for Houses in same city
# * 'Area Population': Population of city house is located in
# * 'Price': Price that the house sold at
# * 'Address': Address for the house

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df = pd.read_csv('USA_Housing.csv')

df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.46                 5.68                       7.01
# 1          79248.64                 6.00                       6.73
# 2          61287.07                 5.87                       8.51
# 3          63345.24                 7.19                       5.59
# 4          59982.20                 5.04                       7.84
#
#    Avg. Area Number of Bedrooms  Area Population      Price  \
# 0                          4.09         23086.80 1059033.56
# 1                          3.09         40173.07 1505890.91
# 2                          5.13         36882.16 1058987.99
# 3                          3.26         34310.24 1260616.81
# 4                          4.23         26354.11  630943.49
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.isnull().sum()  #Checking for NAS in our data
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %% [markdown]
# Changing the data type in a column

# %%
df['Price'] = df['Price'].astype(np.int64)

# %%
df["Price"] = pd.to_numeric(df["Price"])

# %%
# Q 
#TODO 
'''Using housing data, check the various assumptioms of linear regression
linearity
Normality
Collinearity
Outliers
Homosteacitity'''
# Out:
# 'Using housing data, check the various assumptioms of linear regression\nlinearity\nNormality\nCollinearity\nOutliers\nHomosteacitity'

# %% [markdown]
# ### Feature engineering

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                          1.00                -0.00
# Avg. Area House Age                      -0.00                 1.00
# Avg. Area Number of Rooms                -0.01                -0.01
# Avg. Area Number of Bedrooms              0.02                 0.01
# Area Population                          -0.02                -0.02
# Price                                     0.64                 0.45
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                                  -0.01
# Avg. Area House Age                               -0.01
# Avg. Area Number of Rooms                          1.00
# Avg. Area Number of Bedrooms                       0.46
# Area Population                                    0.00
# Price                                              0.34
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
plt.figure(figsize = (12,6))

sns.heatmap(df.corr(), annot = True, cbar = False)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %% [markdown]
# #### Separating independent variables from dependent variable(or target variable)

# %%
y=df["Price"].values
print(y)
# Out:
# [1059033 1505890 1058987 ... 1030729 1198656 1298950]

# %%
x=df.drop(["Price"], axis=1).values
print(x)
# Out:
# [[79545.45857431678 5.682861321615587 7.009188142792237 4.09
#   23086.800502686456
#   '208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101']
#  [79248.64245482568 6.0028998082752425 6.730821019094919 3.09
#   40173.07217364482
#   '188 Johnson Views Suite 079\nLake Kathleen, CA 48958']
#  [61287.067178656784 5.865889840310001 8.512727430375099 5.13
#   36882.15939970458 '9127 Elizabeth Stravenue\nDanieltown, WI 06482-3489']
#  ...
#  [63390.68688550463 7.250590614779546 4.805080980291155 2.13
#   33266.145489652175
#   '4215 Tracy Garden Suite 076\nJoshualand, VA 01707-9165']
#  [68001.33123508695 5.534388416220344 7.130143864349472 5.44
#   42625.62015585088 'USS Wallace\nFPO AE 73316']
#  [65510.581803666224 5.992305307333977 6.792336104424982 4.07
#   46501.28380314165
#   '37778 George Ridges Apt. 509\nEast Holly, NV 29290-3595']]

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]

X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             79545.46                 5.68                       7.01
# 1             79248.64                 6.00                       6.73
# 2             61287.07                 5.87                       8.51
# 3             63345.24                 7.19                       5.59
# 4             59982.20                 5.04                       7.84
# ...                ...                  ...                        ...
# 4995          60567.94                 7.83                       6.14
# 4996          78491.28                 7.00                       6.58
# 4997          63390.69                 7.25                       4.81
# 4998          68001.33                 5.53                       7.13
# 4999          65510.58                 5.99                       6.79
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09         23086.80
# ...

# %% [markdown]
# X = df[ : , 0:5]
#
# X

# %%
y = df['Price']

y
# Out:
# 0       1059033
# 1       1505890
# 2       1058987
# 3       1260616
# 4        630943
#          ...
# 4995    1060193
# 4996    1482617
# 4997    1030729
# 4998    1198656
# 4999    1298950
# Name: Price, Length: 5000, dtype: int64

# %% [markdown]
# #### ii) Splitting data into train and test sets

# %% [markdown]
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101) #The next is to train the model on the training set

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2654          86690.87                 6.26                       6.68
# 2468          59866.95                 5.87                       5.90
# 290           74372.14                 6.56                       8.18
# 1463          61370.32                 6.53                       6.61
# 4508          52652.65                 5.69                       7.22
# ...                ...                  ...                        ...
# 4171          56610.64                 4.85                       7.56
# 599           70596.85                 6.55                       6.54
# 1361          55621.90                 3.74                       6.87
# 1547          63044.46                 5.94                       5.91
# 4959          75078.79                 7.64                       8.44
#
#       Avg. Area Number of Bedrooms  Area Population
# 2654                          3.23         42589.62
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
X_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1718          66775.00                 5.72                       7.80
# 2511          62184.54                 4.93                       7.43
# 345           73643.06                 6.77                       8.34
# 2521          61909.04                 6.23                       6.59
# 54            72942.71                 4.79                       7.32
# ...                ...                  ...                        ...
# 3412          57311.55                 5.26                       7.82
# 4020          76856.30                 5.51                       6.47
# 4635          59861.63                 8.10                       6.26
# 1700          59030.17                 6.16                       5.30
# 790           64506.79                 6.38                       7.55
#
#       Avg. Area Number of Bedrooms  Area Population
# 1718                          4.32         36788.98
# ...

# %% [markdown]
# **Train the model on the training set**

# %% [markdown]
# #### iii) Calling the algorithm
#
# - Here is where one decides what algorithm will perform the learning.
# - The kind of data one has and the output they expect from it informs this decision.
# - Thus if ones's data follows the format that there is a certain variable, a dependent feature (e.g price), that depends on some other independent features (e.g population, income), and the output one expects can take over a range of values, such as price, then the Linear Regression algorithm is a good place to start.

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression() #creating an instance of the algorithm. This will help in reusing it.

# %%
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ***predict the test set results***

# %% [markdown]
# #### iv) Intepreting the model

# %%
linear_regression.intercept_
# Out:
# -2641373.089840048

# %%
linear_regression.coef_
# Out:
# array([2.16176343e+01, 1.65221121e+05, 1.21405375e+05, 1.31871740e+03,
#        1.52251951e+01])

# %%
print('y = - 2641372.66730168 + 2.16176350e+01 (x1) + 1.65221120e+05(x2) + 1.21405377e+05(x3) + 1.31871878e+03(x4) + \
1.52251955e+01(x5)') #This is the learnt model
# Out:
# y = - 2641372.66730168 + 2.16176350e+01 (x1) + 1.65221120e+05(x2) + 1.21405377e+05(x3) + 1.31871878e+03(x4) + 1.52251955e+01(x5)

# %%
X_train.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns = ['Coefficient'])

coeff_df
# Out:
#                               Coefficient
# Avg. Area Income                    21.62
# Avg. Area House Age             165221.12
# Avg. Area Number of Rooms       121405.37
# Avg. Area Number of Bedrooms      1318.72
# Area Population                     15.23

# %% [markdown]
# Interpreting the coefficients:
#
# - Holding all other features fixed, a 1 unit increase in **Avg. Area Income** is associated with an **increase of \$21.61 **.
# - Holding all other features fixed, a 1 unit increase in **Avg. Area House Age** is associated with an **increase of \$1652213.12 **.
# - Holding all other features fixed, a 1 unit increase in **Avg. Area Number of Rooms** is associated with an **increase of \$121405.38 **.
# - Holding all other features fixed, a 1 unit increase in **Avg. Area Number of Bedrooms** is associated with an **increase of \$1318.72 **.
# - Holding all other features fixed, a 1 unit increase in **Area Population** is associated with an **increase of \$15.22 **.
#
# Does this make sense? Probably not because I made up this data. If you want real data to repeat this sort of analysis, check out the [boston dataset](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html):

# %% [markdown]
# #### v) Making predictions to assess the accuracy of the model
# - In as much as a model has been created for us, how much can we trust the outputs from that model when data it has not interacted with before is passed to it?
# - To look into this, we make predictions using the independent features in the test set and then compare those results to the actual values from the test set as well. If the values are too far apart, then the model is not too accurate and some hyper parameter tuning can be performed. If the values are not too far apart, then one can now lift that model and apply it to data that it has not seen before. This is done by calling the `.predict()` function on the X_test.

# %%
y_pred = linear_regression.predict(X_test)

y_pred
# Out:
# array([1258934.39835486,  822694.14192956, 1742213.89281096, ...,
#        1452640.47677641,  645796.65179479, 1364943.26374675])

# %%
linear_regression.predict([[79545.46,5.68,7.01,4.09,23086.80]])
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1224613.80834766])

# %%
residuals = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred, "Difference":y_test-y_pred})


residuals.head(20)
# Out:
#        Actual  Predicted  Difference
# 1718  1251688 1258934.40    -7246.40
# 2511   873048  822694.14    50353.86
# 345   1696977 1742213.89   -45236.89
# 2521  1063964  972936.52    91027.48
# 54     948788  994545.49   -45757.49
# 2866   730043  644485.85    85557.15
# 2371  1166925 1078070.54    88854.46
# 2952   705444  854755.55  -149311.55
# 45    1499988 1445900.85    54087.15
# 4653  1288199 1203354.62    84844.38
# 891   1441736 1455795.51   -14059.51
# 3011  1279681 1299340.83   -19659.83
# 335   1754969 1736577.28    18391.72
# 3050  1511653 1337267.18   174385.82
# 3850  1441956 1389084.65    52871.35
# 834   1119992 1223716.53  -103724.53
# 3188   727866  615897.49   111968.51
# 4675  1138885  964603.92   174281.08
# 2564  1074263 1222875.07  -148612.07
# 1866  1386473 1199048.44   187424.56

# %% [markdown]
# ## Evaluate the model

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9185060956401109

# %% [markdown]
# ## Visualize the predicted results

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted") 
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# #### https://scikit-learn.org/stable/modules/model_evaluation.html#:~:text=The%20sklearn.,values%2C%20or%20binary%20decisions%20values.
#
# - The algorithm that was used to learn is what informs what metrics that will be used to evaluate the model. The link above is to the sklearn docs on the different metrics for different algorithms.

# %% [markdown]
# ## Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn import metrics

# %%
print('MAE', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# MAE 81257.55749899495

# %%
print('MAE', metrics.mean_absolute_error(y_test, y_pred))
print('MSE', metrics.mean_squared_error(y_test, y_pred))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE 81257.55749899495
# MSE 10169125406.591738
# RMSE 100842.08152647255

# %%
X_test.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')
