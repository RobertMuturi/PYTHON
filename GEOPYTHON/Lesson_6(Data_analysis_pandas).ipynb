# %% [markdown]
# # PROCESSING DATA WITH PYTHON 2

# %%
import pandas as pd

# %%
fp = "C:/Users/Joe/Documents/PYTHON/GEOPYTHON/data/029440.txt"

data = pd.read_csv(fp, delim_whitespace=True, na_values=["*", "**", "***", "****", "*****", "******"])
# Out:
# C:\Users\Joe\AppData\Local\Temp\ipykernel_23580\488596101.py:3: DtypeWarning: Columns (29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(fp, delim_whitespace=True, na_values=["*", "**", "***", "****", "*****", "******"])

# %%
data.head()
# Out:
#     USAF   WBAN  YR--MODAHRMN    DIR  SPD  GUS  CLG  SKC   L   M  ...     SLP  \
# 0  29440  99999  190601010600   90.0  7.0  NaN  NaN  OVC NaN NaN  ...  1011.0
# 1  29440  99999  190601011300    NaN  0.0  NaN  NaN  OVC NaN NaN  ...  1015.5
# 2  29440  99999  190601012000    NaN  0.0  NaN  NaN  OVC NaN NaN  ...  1016.2
# 3  29440  99999  190601020600    NaN  0.0  NaN  NaN  CLR NaN NaN  ...  1016.2
# 4  29440  99999  190601021300  270.0  7.0  NaN  NaN  OVC NaN NaN  ...  1015.6
#
#    ALT  STP  MAX  MIN  PCP01  PCP06  PCP24  PCPXX  SD
# 0  NaN  NaN  NaN  NaN    NaN    NaN    NaN    NaN NaN
# 1  NaN  NaN  NaN  NaN    NaN    NaN    NaN    NaN NaN
# 2  NaN  NaN  NaN  NaN    NaN    NaN    NaN    NaN NaN
# 3  NaN  NaN  NaN  NaN    NaN    NaN    NaN    NaN NaN
# 4  NaN  NaN  NaN  NaN    NaN    NaN    NaN    NaN NaN
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['USAF', 'WBAN', 'YR--MODAHRMN', 'DIR', 'SPD', 'GUS', 'CLG', 'SKC', 'L',
#        'M', 'H', 'VSB', 'MW', 'MW.1', 'MW.2', 'MW.3', 'AW', 'AW.1', 'AW.2',
#        'AW.3', 'W', 'TEMP', 'DEWP', 'SLP', 'ALT', 'STP', 'MAX', 'MIN', 'PCP01',
#        'PCP06', 'PCP24', 'PCPXX', 'SD'],
#       dtype='object')

# %%
data = pd.read_csv(fp, delim_whitespace = True, usecols=["USAF", "YR--MODAHRMN", "DIR", "SPD", "GUS", "TEMP", "MAX", "MIN"], na_values=["*", "**", "***", "****", "*****", "******"])

#check data frame
data.head()
# Out:
#     USAF  YR--MODAHRMN    DIR  SPD  GUS  TEMP  MAX  MIN
# 0  29440  190601010600   90.0  7.0  NaN  27.0  NaN  NaN
# 1  29440  190601011300    NaN  0.0  NaN  27.0  NaN  NaN
# 2  29440  190601012000    NaN  0.0  NaN  25.0  NaN  NaN
# 3  29440  190601020600    NaN  0.0  NaN  26.0  NaN  NaN
# 4  29440  190601021300  270.0  7.0  NaN  27.0  NaN  NaN

# %%
#renaming columns using dictionary
#create dictionary with old and new names
new_names = {"YR--MODAHRMN": "TIME", "SPD": "SPEED", "GUS": "GUST"}

#see how it looks
new_names
# Out:
# {'YR--MODAHRMN': 'TIME', 'SPD': 'SPEED', 'GUS': 'GUST'}

# %%
#data type
type(new_names)
# Out:
# dict

# %%
#rename coluns
data = data.rename(columns=new_names)

#print new columns
print(data.columns)
# Out:
# Index(['USAF', 'TIME', 'DIR', 'SPEED', 'GUST', 'TEMP', 'MAX', 'MIN'], dtype='object')

# %%
#renaming temp and usaf
new_names_two = {"USAF": "STATION_NUMBER", "TEMP": "TEMP_F"}
data = data.rename(columns=new_names_two)
data.columns
# Out:
# Index(['STATION_NUMBER', 'TIME', 'DIR', 'SPEED', 'GUST', 'TEMP_F', 'MAX',
#        'MIN'],
#       dtype='object')

# %%
data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN

# %%
data.shape #rows and colmns
# Out:
# (757983, 8)

# %%
data.tail()
# Out:
#         STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN
# 757978           29440  201910012220  130.0    3.0   NaN    39.0  NaN  NaN
# 757979           29440  201910012250  110.0    3.0   NaN    37.0  NaN  NaN
# 757980           29440  201910012300  100.0    2.0   NaN    38.0  NaN  NaN
# 757981           29440  201910012320  100.0    3.0   NaN    37.0  NaN  NaN
# 757982           29440  201910012350  110.0    3.0   NaN    37.0  NaN  NaN

# %%
data.dtypes #data types of columns
# Out:
# STATION_NUMBER      int64
# TIME                int64
# DIR               float64
# SPEED             float64
# GUST              float64
# TEMP_F            float64
# MAX               float64
# MIN               float64
# dtype: object

# %%
data.describe()
# Out:
#        STATION_NUMBER          TIME            DIR          SPEED  \
# count        757983.0  7.579830e+05  699256.000000  750143.000000
# mean          29440.0  1.999974e+11     233.499846       6.742641
# std               0.0  1.629544e+09     209.707258       4.296191
# min           29440.0  1.906010e+11      10.000000       0.000000
# 25%           29440.0  1.989083e+11     130.000000       3.000000
# 50%           29440.0  2.004042e+11     200.000000       7.000000
# 75%           29440.0  2.012050e+11     270.000000       9.000000
# max           29440.0  2.019100e+11     990.000000      61.000000
#
#                GUST         TEMP_F           MAX           MIN
# count  19906.000000  754862.000000  23869.000000  23268.000000
# mean      20.147996      40.409778     45.373539     35.783737
# std        7.415138      17.898715     18.242679     17.195427
# min       11.000000     -33.000000    -26.000000    -32.000000
# ...

# %%
round(data.describe(), 2)
# Out:
#        STATION_NUMBER          TIME        DIR      SPEED      GUST  \
# count        757983.0  7.579830e+05  699256.00  750143.00  19906.00
# mean          29440.0  1.999974e+11     233.50       6.74     20.15
# std               0.0  1.629544e+09     209.71       4.30      7.42
# min           29440.0  1.906010e+11      10.00       0.00     11.00
# 25%           29440.0  1.989083e+11     130.00       3.00     14.00
# 50%           29440.0  2.004042e+11     200.00       7.00     18.00
# 75%           29440.0  2.012050e+11     270.00       9.00     26.00
# max           29440.0  2.019100e+11     990.00      61.00    108.00
#
#           TEMP_F       MAX       MIN
# count  754862.00  23869.00  23268.00
# mean       40.41     45.37     35.78
# std        17.90     18.24     17.20
# min       -33.00    -26.00    -32.00
# 25%        29.00     32.00     26.00
# 50%        39.00     44.00     36.00
# 75%        54.00     60.00     49.00
# max        91.00     91.00     81.00

# %% [markdown]
# # USE FUNCTIONS IN PANDAS

# %%
def fahr_to_celsius(temp_fahrenheit):
    """Function to convert Fahrenheit temperature into Celsius.

    Parameters
    ----------

    temp_fahrenheit: int | float
        Input temperature in Fahrenheit (should be a number)

    Returns
    -------

    Temperature in Celsius (float)
    """

    # Convert the Fahrenheit into Celsius 
    converted_temp = (temp_fahrenheit - 32) / 1.8
    
    return converted_temp

# %%
fahr_to_celsius(32.0)
# Out:
# 0.0

# %% [markdown]
# Iterating over rows
#
# We can apply the function one row at a time using a for loop and the iterrows() method. This will allow us to iterate row by row using iterrows() in a for loop to repeat a given process for each row in a pandas DataFrame. Please note that iterating over rows is a rather inefficient approach, but it is still useful to understand the logic behind the iteration.
#
# When using the iterrows() method it is important to understand that iterrows() accesses not only the values of one row, but also the index of the row as well.
#
# Let’s start with a simple for loop that goes through each row in our DataFrame.

# %%
#iterate over the rows
for idx, row in data.iterrows():
    
    #print index value
    print(f"index: {idx}")
    
    #print rows
    print(f"Temp F: {row['TEMP_F']}\n")
    
    break #break loop
# Out:
# index: 0
# Temp F: 27.0

# %%
#temp conversion
data["TEMP_C"] = 0.0

#iterate over the rows
for idx, row in data.iterrows():
    
    #convert fahr to celsius
    celsius = fahr_to_celsius(row["TEMP_F"])
    
    #UPDATE value of celsius column with converted value
    data.at[idx, "TEMP_C"] = celsius

# %%
data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C
# 0 -2.777778
# 1 -2.777778
# 2 -3.888889
# 3 -3.333333
# 4 -2.777778

# %% [markdown]
# # APPLYING THE FUNCTION
#
# pandas DataFrames and Series have a dedicated method .apply() for applying functions on columns (or rows!). When using .apply(), we pass the function name (without parentheses!) as an argument to the apply() method. Let’s start by applying the function to the TEMP_F column that contains the temperature values in Fahrenheit.

# %%
data["TEMP_F"].apply(fahr_to_celsius)
# Out:
# 0        -2.777778
# 1        -2.777778
# 2        -3.888889
# 3        -3.333333
# 4        -2.777778
#             ...
# 757978    3.888889
# 757979    2.777778
# 757980    3.333333
# 757981    2.777778
# 757982    2.777778
# Name: TEMP_F, Length: 757983, dtype: float64

# %%
#better way to do it
data["TEMP_C"] = data["TEMP_F"].apply(fahr_to_celsius)

# %% [raw]
# #can also be done for multiple columns
# data[["TEMP_F", "MIN", "MAX"]].apply(fahr_to_celsius)

# %%
data[["MIN_C", "MAX_C"]] = data[["MIN", "MAX"]].apply(fahr_to_celsius)
data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C  MIN_C  MAX_C
# 0 -2.777778    NaN    NaN
# 1 -2.777778    NaN    NaN
# 2 -3.888889    NaN    NaN
# 3 -3.333333    NaN    NaN
# 4 -2.777778    NaN    NaN

# %% [markdown]
# # Parsing dates

# %%
data["TIME"].head(10)
# Out:
# 0    190601010600
# 1    190601011300
# 2    190601012000
# 3    190601020600
# 4    190601021300
# 5    190601022000
# 6    190601030600
# 7    190601031300
# 8    190601032000
# 9    190601040600
# Name: TIME, dtype: int64

# %%
data["TIME"].tail(10)
# Out:
# 757973    201910012050
# 757974    201910012100
# 757975    201910012120
# 757976    201910012150
# 757977    201910012200
# 757978    201910012220
# 757979    201910012250
# 757980    201910012300
# 757981    201910012320
# 757982    201910012350
# Name: TIME, dtype: int64

# %%
#convert to string inorder to get date, years etc
data["TIME_STR"] = data["TIME"].astype(str)

# %%
#string slicing
date =  "201910012350"
date[0:6]
# Out:
# '201910'

# %%
data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C  MIN_C  MAX_C      TIME_STR
# 0 -2.777778    NaN    NaN  190601010600
# 1 -2.777778    NaN    NaN  190601011300
# 2 -3.888889    NaN    NaN  190601012000
# 3 -3.333333    NaN    NaN  190601020600
# 4 -2.777778    NaN    NaN  190601021300

# %%
data.dtypes
# Out:
# STATION_NUMBER      int64
# TIME                int64
# DIR               float64
# SPEED             float64
# GUST              float64
# TEMP_F            float64
# MAX               float64
# MIN               float64
# TEMP_C            float64
# MIN_C             float64
# MAX_C             float64
# TIME_STR           object
# dtype: object

# %%
#slice the string
data["YEAR_MONTH"] = data["TIME_STR"].str.slice(start=0, stop=6) #same as above

data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C  MIN_C  MAX_C      TIME_STR YEAR_MONTH
# 0 -2.777778    NaN    NaN  190601010600     190601
# 1 -2.777778    NaN    NaN  190601011300     190601
# 2 -3.888889    NaN    NaN  190601012000     190601
# 3 -3.333333    NaN    NaN  190601020600     190601
# 4 -2.777778    NaN    NaN  190601021300     190601

# %%
#extract month into new column
data["MONTH"] = data["TIME_STR"].str.slice(start=4, stop=6) 
data[["MONTH", "YEAR_MONTH"]]
# Out:
#        MONTH YEAR_MONTH
# 0         01     190601
# 1         01     190601
# 2         01     190601
# 3         01     190601
# 4         01     190601
# ...      ...        ...
# 757978    10     201910
# 757979    10     201910
# 757980    10     201910
# 757981    10     201910
# 757982    10     201910
#
# [757983 rows x 2 columns]

# %% [markdown]
# # DATE TIME

# %%
#convert character strings to datetime
data["DATE"] = pd.to_datetime(data["TIME_STR"])

# %%
#OUTPUT
data["DATE"].head()
# Out:
# 0   1906-01-01 06:00:00
# 1   1906-01-01 13:00:00
# 2   1906-01-01 20:00:00
# 3   1906-01-02 06:00:00
# 4   1906-01-02 13:00:00
# Name: DATE, dtype: datetime64[ns]

# %%
#year
data["DATE"].dt.year
# Out:
# 0         1906
# 1         1906
# 2         1906
# 3         1906
# 4         1906
#           ...
# 757978    2019
# 757979    2019
# 757980    2019
# 757981    2019
# 757982    2019
# Name: DATE, Length: 757983, dtype: int64

# %%
#month
data["DATE"].dt.month
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 757978    10
# 757979    10
# 757980    10
# 757981    10
# 757982    10
# Name: DATE, Length: 757983, dtype: int64

# %%
#we can check the number of unique years in our input data:
data["DATE"].dt.year.nunique()
# Out:
# 51

# %%
# Convert to datetime and keep only year and month
data["YEAR_MONTH_DT"] = pd.to_datetime(data["TIME_STR"], format="%Y%m", exact=False)

#'''exact=False finds the characters matching the specified format and drops out the rest (days, hours and minutes are excluded in the output).'''

# %%
data["YEAR_MONTH_DT"]
# Out:
# 0        1906-01-01
# 1        1906-01-01
# 2        1906-01-01
# 3        1906-01-01
# 4        1906-01-01
#             ...
# 757978   2019-10-01
# 757979   2019-10-01
# 757980   2019-10-01
# 757981   2019-10-01
# 757982   2019-10-01
# Name: YEAR_MONTH_DT, Length: 757983, dtype: datetime64[ns]

# %% [markdown]
# # Aggregating data in pandas by grouping

# %% [markdown]
# Here, we will learn how to use pandas.DataFrame.groupby, which is a handy method for compressing large amounts of data and computing statistics for subgroups.
#
# In our case, we will use the groupby method to calculate the average temperatures for each month through these three steps:
#
# - Grouping the data based on the year and month
#
# - Calculating the average for each month (each group)
#
# - Storing those values into a new DataFrame called monthly_data
#
# Before we start grouping the data, let’s once again see what our data looks like.

# %%
print(f"rows: {len(data)}")
# Out:
# rows: 757983

# %%
data.head()
# Out:
#    STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C  MIN_C  MAX_C      TIME_STR YEAR_MONTH MONTH                DATE  \
# 0 -2.777778    NaN    NaN  190601010600     190601    01 1906-01-01 06:00:00
# 1 -2.777778    NaN    NaN  190601011300     190601    01 1906-01-01 13:00:00
# 2 -3.888889    NaN    NaN  190601012000     190601    01 1906-01-01 20:00:00
# 3 -3.333333    NaN    NaN  190601020600     190601    01 1906-01-02 06:00:00
# 4 -2.777778    NaN    NaN  190601021300     190601    01 1906-01-02 13:00:00
#
#   YEAR_MONTH_DT
# 0    1906-01-01
# 1    1906-01-01
# 2    1906-01-01
# ...

# %%
#group the data
grouped = data.groupby("YEAR_MONTH")

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(grouped) #data from unique months in groups
# Out:
# 601

# %%
data["YEAR_MONTH"].nunique()
# Out:
# 601

# %%
grouped.groups.keys()
# Out:
# dict_keys(['190601', '190602', '190603', '190604', '190605', '190606', '190607', '190608', '190609', '190610', '190611', '190612', '190701', '190702', '190703', '190704', '190705', '190706', '190707', '190708', '190709', '190710', '190711', '190712', '190801', '190802', '190803', '190804', '190805', '190806', '190807', '190808', '190809', '190810', '190811', '190812', '190901', '190902', '190903', '190904', '190905', '190906', '190907', '190908', '190909', '190910', '190911', '190912', '191001', '191002', '191003', '191004', '191005', '191006', '191007', '191008', '191009', '191010', '191011', '191012', '191101', '191102', '191103', '191104', '191105', '191106', '191107', '191108', '191109', '191110', '191111', '191112', '191201', '191202', '191203', '191204', '191205', '191206', '191207', '191208', '191209', '191210', '191211', '191212', '191301', '191302', '191303', '191304', '191305', '191306', '191307', '191308', '191309', '191310', '191311', '191312', '191401', '191402', '191403
# ...

# %% [markdown]
# # Accessing data for one group

# %%
#specify a month
month = "201908"

#select group
group1 = grouped.get_group(month)

# %%
#output
group1
# Out:
#         STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 753566           29440  201908010000  360.0    0.0   NaN    47.0  NaN  NaN
# 753567           29440  201908010020    NaN    0.0   NaN    46.0  NaN  NaN
# 753568           29440  201908010050    NaN    0.0   NaN    45.0  NaN  NaN
# 753569           29440  201908010100  360.0    0.0   NaN    44.0  NaN  NaN
# 753570           29440  201908010120    NaN    0.0   NaN    43.0  NaN  NaN
# ...                ...           ...    ...    ...   ...     ...  ...  ...
# 755781           29440  201908312220  180.0    6.0   NaN    59.0  NaN  NaN
# 755782           29440  201908312250  170.0    6.0   NaN    57.0  NaN  NaN
# 755783           29440  201908312300  170.0    7.0   NaN    58.0  NaN  NaN
# 755784           29440  201908312320  160.0    7.0   NaN    57.0  NaN  NaN
# 755785           29440  201908312350  180.0    6.0   NaN    57.0  NaN  NaN
#
#            TEMP_C  MIN_C  MAX_C      TIME_STR YEAR_MONTH MONTH  \
# ...

# %%
type(group1)
# Out:
# pandas.core.frame.DataFrame

# %%
#calculate mean for some of the columns
mean_cols = ["DIR", "SPEED", "GUST", "TEMP_F", "TEMP_C"]

#calc mean at go
mean_values = group1[mean_cols].mean()

mean_values
# Out:
# DIR       320.335766
# SPEED       6.769447
# GUST       15.751678
# TEMP_F     60.598649
# TEMP_C     15.888138
# dtype: float64

# %% [markdown]
# # For loops and grouped objects
# When iterating over the groups in our DataFrameGroupBy object it is important to understand that a single group in our DataFrameGroupBy actually contains not only the actual values, but also information about the key that was used to do the grouping. Hence, when iterating over the data we need to assign the key and the values into separate variables.
#
# So, let’s see how we can iterate over the groups and print the key and the data from a single group (again using break to only see what is happening for the first group).

# %%
#iterate over groups
for key, group in grouped:
    #print key and group
    print(f"Key:\n {key}")
    print(f"\n First rows of data in this group:\n {group.head()}")
    
    #stop iteration
    break
# Out:
# Key:
#  190601
#
#  First rows of data in this group:
#     STATION_NUMBER          TIME    DIR  SPEED  GUST  TEMP_F  MAX  MIN  \
# 0           29440  190601010600   90.0    7.0   NaN    27.0  NaN  NaN
# 1           29440  190601011300    NaN    0.0   NaN    27.0  NaN  NaN
# 2           29440  190601012000    NaN    0.0   NaN    25.0  NaN  NaN
# 3           29440  190601020600    NaN    0.0   NaN    26.0  NaN  NaN
# 4           29440  190601021300  270.0    7.0   NaN    27.0  NaN  NaN
#
#      TEMP_C  MIN_C  MAX_C      TIME_STR YEAR_MONTH MONTH                DATE  \
# 0 -2.777778    NaN    NaN  190601010600     190601    01 1906-01-01 06:00:00
# 1 -2.777778    NaN    NaN  190601011300     190601    01 1906-01-01 13:00:00
# 2 -3.888889    NaN    NaN  190601012000     190601    01 1906-01-01 20:00:00
# 3 -3.333333    NaN    NaN  190601020600     190601    01 1906-01-02 06:00:00
# 4 -2.777778    NaN    NaN  190601021300     190601    01 1906-01-02 13:00:00
#
#   YEAR_MONTH_DT
# ...

# %%
# create empty dataframe for aggregated values
monthly_data = pd.DataFrame()

#columns to aggregate
mean_cols = ["DIR", "SPEED", "GUST", "TEMP_F", "TEMP_C"]

#iterate over the groups
for key, group in grouped:
    #calc mean
    mean_values = group[mean_cols].mean()
    
    # Add the ´key´ (i.e. the date+time information) into the aggregated values
    mean_values["YEAR_MONTH"] = key
    
    # Convert the mean_values series to a DataFrame and make it have a row orientation
    row = mean_values.to_frame().transpose()
    
    # Concatenate the aggregated values into the monthly_data DataFrame
    monthly_data = pd.concat([monthly_data, row], ignore_index=True)

# %%
print(monthly_data)
# Out:
#             DIR      SPEED       GUST     TEMP_F     TEMP_C YEAR_MONTH
# 0    218.181818  13.204301        NaN  25.526882  -3.596177     190601
# 1    178.095238  13.142857        NaN  25.797619  -3.445767     190602
# 2    232.043011  15.021505        NaN  22.806452  -5.107527     190603
# 3    232.045455  13.811111        NaN  38.822222   3.790123     190604
# 4    192.820513  10.333333        NaN  55.526882   13.07049     190605
# ..          ...        ...        ...        ...        ...        ...
# 596  370.992008    8.13849  17.251852    61.7434  16.524111     201906
# 597  294.433641   5.785714  15.034722  61.569955  16.427753     201907
# 598  320.335766   6.769447  15.751678  60.598649  15.888138     201908
# 599  306.491058   6.363594  15.173285  49.958137   9.976743     201909
# 600  239.577465  10.169014  17.470588  42.774648   5.985915     201910
#
# [601 rows x 6 columns]

# %%
# Finding mean for all groups at once
grouped.mean()
# Out:
#             STATION_NUMBER          TIME         DIR      SPEED       GUST  \
# YEAR_MONTH
# 190601             29440.0  1.906012e+11  218.181818  13.204301        NaN
# 190602             29440.0  1.906021e+11  178.095238  13.142857        NaN
# 190603             29440.0  1.906032e+11  232.043011  15.021505        NaN
# 190604             29440.0  1.906042e+11  232.045455  13.811111        NaN
# 190605             29440.0  1.906052e+11  192.820513  10.333333        NaN
# ...                    ...           ...         ...        ...        ...
# 201906             29440.0  2.019062e+11  370.992008   8.138490  17.251852
# 201907             29440.0  2.019072e+11  294.433641   5.785714  15.034722
# 201908             29440.0  2.019082e+11  320.335766   6.769447  15.751678
# 201909             29440.0  2.019092e+11  306.491058   6.363594  15.173285
# 201910             29440.0  2.019100e+11  239.577465  10.169014  17.470588
#
# ...

# %% [markdown]
# # Detecting Warm Months
#
# Now that we have aggregated our data on monthly level, all we need to do is to sort our results in order to check which years had the warmest April temperatures. A simple approach is to select all Aprils from the data, group the data and check which group(s) have the highest mean value.
#
# We can start this by selecting all records that are from April (regardless of the year).

# %%
#create all records of April
aprils = data[data["MONTH"] == "04"]

# %%
#take subset of columns
aprils = aprils[["STATION_NUMBER", "TEMP_F", "TEMP_C", "YEAR_MONTH"]]

# %%
#We can group by year and month
grouped = aprils.groupby(by="YEAR_MONTH")

# %%
#Calc mean of groups
monthly_mean = grouped.mean()

# %%
monthly_mean.head()
# Out:
#             STATION_NUMBER     TEMP_F    TEMP_C
# YEAR_MONTH
# 190604             29440.0  38.822222  3.790123
# 190704             29440.0  36.111111  2.283951
# 190804             29440.0  36.811111  2.672840
# 190904             29440.0  31.977778 -0.012346
# 191004             29440.0  39.833333  4.351852

# %%
#sort and check highest values
monthly_mean.sort_values(by="TEMP_C", ascending=False).head(10)
# Out:
#             STATION_NUMBER     TEMP_F    TEMP_C
# YEAR_MONTH
# 201904             29440.0  42.472030  5.817794
# 199004             29440.0  41.918084  5.510047
# 198904             29440.0  41.369647  5.205360
# 201104             29440.0  41.290730  5.161517
# 200404             29440.0  41.249676  5.138709
# 200204             29440.0  41.132353  5.073529
# 198304             29440.0  41.016183  5.008991
# 200804             29440.0  40.962343  4.979079
# 200004             29440.0  40.777778  4.876543
# 199904             29440.0  40.695291  4.830717

# %% [markdown]
# # Repeating the data analysis with a larger dataset
# To wrap up today’s lesson, let’s repeat the data analysis steps above for all the available data we have (!). First, it would be good to confirm the path to the directory where all the input data are located.
#
# The idea is, that we will repeat the analysis process for each input file using a (rather long) for loop! Here we have all the main analysis steps with some additional output info, all in one long code cell.

# %%
# Read selected columns of  data using varying amount of spaces as separator and specifying * characters as NoData values
data = pd.read_csv(
    fp,
    delim_whitespace=True,
    usecols=["USAF", "YR--MODAHRMN", "DIR", "SPD", "GUS", "TEMP", "MAX", "MIN"],
    na_values=["*", "**", "***", "****", "*****", "******"],
)

# Rename the columns
new_names = {
    "USAF": "STATION_NUMBER",
    "YR--MODAHRMN": "TIME",
    "SPD": "SPEED",
    "GUS": "GUST",
    "TEMP": "TEMP_F",
}
data = data.rename(columns=new_names)

# Print info about the current input file:
print(f"STATION NUMBER: {data.at[0, 'STATION_NUMBER']}")
print(f"NUMBER OF OBSERVATIONS: {len(data)}")

# Create column
col_name = "TEMP_C"
data[col_name] = None

# Convert tempetarues from Fahrenheits to Celsius
data["TEMP_C"] = data["TEMP_F"].apply(fahr_to_celsius)

# Convert TIME to string
data["TIME_STR"] = data["TIME"].astype(str)

# Parse year and month
data["MONTH"] = data["TIME_STR"].str.slice(start=5, stop=6).astype(int)
data["YEAR"] = data["TIME_STR"].str.slice(start=0, stop=4).astype(int)

# Extract observations for the months of April
aprils = data[data["MONTH"] == 4]

# Take a subset of columns
aprils = aprils[["STATION_NUMBER", "TEMP_F", "TEMP_C", "YEAR", "MONTH"]]

# Group by year and month
grouped = aprils.groupby(by=["YEAR", "MONTH"])

# Get mean values for each group
monthly_mean = grouped.mean()

# Print info
print(monthly_mean.sort_values(by="TEMP_C", ascending=False).head(5))
print("\n")
# Out:
# STATION NUMBER: 29440
# NUMBER OF OBSERVATIONS: 757983
#             STATION_NUMBER     TEMP_F    TEMP_C
# YEAR MONTH
# 2019 4             29440.0  42.472030  5.817794
# 1990 4             29440.0  41.918084  5.510047
# 1989 4             29440.0  41.369647  5.205360
# 2011 4             29440.0  41.290730  5.161517
# 2004 4             29440.0  41.249676  5.138709

# %%
print(data.at[0, "STATION_NUMBER"])
# Out:
# 29440

# %% [markdown]
# At this point we will use the glob() function from the module glob to list our input files. glob is a handy function for finding files in a directrory that match a given pattern, for example.

# %%
import glob

# %%
file_list = glob.glob("C:/Users/Joe/Documents/GEOPYTHON/data/0*txt")
#you want files that start with 0 and end with txt, * is whats in btwn

# %% [markdown]
# Note that we’re using the * character as a wildcard, so any file that starts with data/0 and ends with txt will be added to the list of files we will iterate over. We specifically use data/0 as the starting part of the file names to avoid having our metadata files included in the list!

# %%
print(f"Numbr of files in the list: {len(file_list)}")
print(file_list)
# Out:
# Numbr of files in the list: 0
# []

# %%
#we can now loop over all the files
for fp in file_list:
    print(fp)

# %%
# Repeat the analysis steps for each input file:
for fp in file_list:

    # Read selected columns of  data using varying amount of spaces as separator and specifying * characters as NoData values
    data = pd.read_csv(
        fp,
        delim_whitespace=True,
        usecols=["USAF", "YR--MODAHRMN", "DIR", "SPD", "GUS", "TEMP", "MAX", "MIN"],
        na_values=["*", "**", "***", "****", "*****", "******"],
    )

    # Rename the columns
    new_names = {
        "USAF": "STATION_NUMBER",
        "YR--MODAHRMN": "TIME",
        "SPD": "SPEED",
        "GUS": "GUST",
        "TEMP": "TEMP_F",
    }
    data = data.rename(columns=new_names)

    # Print info about the current input file:
    print(f"STATION NUMBER: {data.at[0, 'STATION_NUMBER']}")
    print(f"NUMBER OF OBSERVATIONS: {len(data)}")

    # Create column
    col_name = "TEMP_C"
    data[col_name] = None

    # Convert tempetarues from Fahrenheits to Celsius
    data["TEMP_C"] = data["TEMP_F"].apply(fahr_to_celsius)

    # Convert TIME to string
    data["TIME_STR"] = data["TIME"].astype(str)

    # Parse year and month
    data["MONTH"] = data["TIME_STR"].str.slice(start=5, stop=6).astype(int)
    data["YEAR"] = data["TIME_STR"].str.slice(start=0, stop=4).astype(int)

    # Extract observations for the months of April
    aprils = data[data["MONTH"] == 4]

    # Take a subset of columns
    aprils = aprils[["STATION_NUMBER", "TEMP_F", "TEMP_C", "YEAR", "MONTH"]]

    # Group by year and month
    grouped = aprils.groupby(by=["YEAR", "MONTH"])

    # Get mean values for each group
    monthly_mean = grouped.mean()

    # Print info
    print(monthly_mean.sort_values(by="TEMP_C", ascending=False).head(5))
    print("\n")

# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# ## PROBLEM 1
# Reading in a tricky data file

# %%
import pandas as pd

# %%
#Read the data

fp = "C:/Users/Joe/Documents/PYTHON/GEOPYTHON/1091402.txt"

data = pd.read_csv(fp, delim_whitespace=True, skiprows=[1], na_values=-9999)

# %%
data.head()
# Out:
#              STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  TAVG  \
# 0  GHCND:FIE00142080         51   60.3269    24.9603  19520101  0.31  37.0
# 1  GHCND:FIE00142080         51   60.3269    24.9603  19520102   NaN  35.0
# 2  GHCND:FIE00142080         51   60.3269    24.9603  19520103  0.14  33.0
# 3  GHCND:FIE00142080         51   60.3269    24.9603  19520104  0.05  29.0
# 4  GHCND:FIE00142080         51   60.3269    24.9603  19520105  0.06  27.0
#
#    TMAX  TMIN
# 0  39.0  34.0
# 1  37.0  34.0
# 2  36.0   NaN
# 3  30.0  25.0
# 4  30.0  25.0

# %%
data.describe()
# Out:
#        ELEVATION      LATITUDE     LONGITUDE          DATE          PRCP  \
# count    23716.0  2.371600e+04  2.371600e+04  2.371600e+04  22163.000000
# mean        51.0  6.032690e+01  2.496030e+01  1.984792e+07      0.074320
# std          0.0  1.319506e-11  4.227818e-12  1.882901e+05      0.161391
# min         51.0  6.032690e+01  2.496030e+01  1.952010e+07      0.000000
# 25%         51.0  6.032690e+01  2.496030e+01  1.968123e+07      0.000000
# 50%         51.0  6.032690e+01  2.496030e+01  1.985032e+07      0.000000
# 75%         51.0  6.032690e+01  2.496030e+01  2.001071e+07      0.070000
# max         51.0  6.032690e+01  2.496030e+01  2.017100e+07      2.580000
#
#                TAVG          TMAX          TMIN
# count  20408.000000  23456.000000  23351.000000
# mean      41.324089     47.999062     34.185731
# std       16.688849     18.180119     16.432265
# min      -30.000000    -27.000000    -33.000000
# 25%       31.000000     34.000000     25.000000
# ...

# %%
data.tail()
# Out:
#                  STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  \
# 23711  GHCND:FIE00142080         51   60.3269    24.9603  20170930   NaN
# 23712  GHCND:FIE00142080         51   60.3269    24.9603  20171001  0.04
# 23713  GHCND:FIE00142080         51   60.3269    24.9603  20171002   NaN
# 23714  GHCND:FIE00142080         51   60.3269    24.9603  20171003  0.94
# 23715  GHCND:FIE00142080         51   60.3269    24.9603  20171004  0.51
#
#        TAVG  TMAX  TMIN
# 23711  47.0  49.0  44.0
# 23712  47.0  48.0  45.0
# 23713  47.0  49.0  46.0
# 23714  47.0   NaN  44.0
# 23715  52.0  56.0   NaN

# %%
#how many no-data values are in the TAVG colum
tavg_nodata_count = data["TAVG"].isna().sum()
print(f'Number of no-data values in column "TAVG": {tavg_nodata_count}')
# Out:
# Number of no-data values in column "TAVG": 3308

# %%
#how many no-data values are in the TMIN colum
tmin_nodata_count = data["TMIN"].isna().sum()
print(f'Number of no-data values in column "TMIN": {tmin_nodata_count}')
# Out:
# Number of no-data values in column "TMIN": 365

# %%
#calculate total number of day covered in this data file.
day_count = len(data["DATE"].unique())
print(f'Number of days: {day_count}')
# Out:
# Number of days: 23716

# %%
#find date of oldest(first) observation
first_obs = data["DATE"].min()
print(f'Date of the first observation: {first_obs}')
# Out:
# Date of the first observation: 19520101

# %%
#find date of recent observation
last_obs = data["DATE"].max()
print(f'Date of the last observation: {last_obs}')
# Out:
# Date of the last observation: 20171004

# %%
# the average temperature for the whole data file (all observtions) from column TAVG
avg_temp = data["TAVG"].mean()
print(f'Average temperature (F) for the whole dataset: {round(avg_temp, 2)}')
# Out:
# Average temperature (F) for the whole dataset: 41.32

# %%
data["DATE"].dtype
# Out:
# dtype('int64')

# %%
#The average TMAX temperature over the Summer of 1969 (months May, June, July, and August of the year 1969)
#create subset of summer of 1969
sum1969 = data.loc[(data["DATE"] >= 19690501) & (data["DATE"] <= 19690831)]

#average temp
avg_temp_1969 = sum1969["TMAX"].mean()
print(f'Average temperature (F) for the Summer of 69: {round(avg_temp_1969, 2)}')
# Out:
# Average temperature (F) for the Summer of 69: 67.82

# %%
avg_temp_1969 = (data["TMAX"].loc[(data["DATE"] >= 19690501) & (data["DATE"] <= 19690831)]).mean()
print(f'Average temperature (F) for the Summer of 69: {round(avg_temp_1969, 2)}')
# Out:
# Average temperature (F) for the Summer of 69: 67.82

# %% [markdown]
# ## PROBLEM 2
# Calculating monthly average temperatures

# %%
data.head()
# Out:
#              STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  TAVG  \
# 0  GHCND:FIE00142080         51   60.3269    24.9603  19520101  0.31  37.0
# 1  GHCND:FIE00142080         51   60.3269    24.9603  19520102   NaN  35.0
# 2  GHCND:FIE00142080         51   60.3269    24.9603  19520103  0.14  33.0
# 3  GHCND:FIE00142080         51   60.3269    24.9603  19520104  0.05  29.0
# 4  GHCND:FIE00142080         51   60.3269    24.9603  19520105  0.06  27.0
#
#    TMAX  TMIN
# 0  39.0  34.0
# 1  37.0  34.0
# 2  36.0   NaN
# 3  30.0  25.0
# 4  30.0  25.0

# %%
#convert date to str
data["DATE_STR"] = data["DATE"].astype(str)
data.head()
# Out:
#              STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  TAVG  \
# 0  GHCND:FIE00142080         51   60.3269    24.9603  19520101  0.31  37.0
# 1  GHCND:FIE00142080         51   60.3269    24.9603  19520102   NaN  35.0
# 2  GHCND:FIE00142080         51   60.3269    24.9603  19520103  0.14  33.0
# 3  GHCND:FIE00142080         51   60.3269    24.9603  19520104  0.05  29.0
# 4  GHCND:FIE00142080         51   60.3269    24.9603  19520105  0.06  27.0
#
#    TMAX  TMIN  DATE_STR
# 0  39.0  34.0  19520101
# 1  37.0  34.0  19520102
# 2  36.0   NaN  19520103
# 3  30.0  25.0  19520104
# 4  30.0  25.0  19520105

# %%
#create column of year and month
data["YEAR_MONTH"] = data["DATE_STR"].str.slice(start=0, stop=6)
data.head()
# Out:
#              STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  TAVG  \
# 0  GHCND:FIE00142080         51   60.3269    24.9603  19520101  0.31  37.0
# 1  GHCND:FIE00142080         51   60.3269    24.9603  19520102   NaN  35.0
# 2  GHCND:FIE00142080         51   60.3269    24.9603  19520103  0.14  33.0
# 3  GHCND:FIE00142080         51   60.3269    24.9603  19520104  0.05  29.0
# 4  GHCND:FIE00142080         51   60.3269    24.9603  19520105  0.06  27.0
#
#    TMAX  TMIN  DATE_STR YEAR_MONTH
# 0  39.0  34.0  19520101     195201
# 1  37.0  34.0  19520102     195201
# 2  36.0   NaN  19520103     195201
# 3  30.0  25.0  19520104     195201
# 4  30.0  25.0  19520105     195201

# %%
#create column of temp_c
data["TEMP_C"] = (data["TAVG"] - 32) / 1.8
data.head()
# Out:
#              STATION  ELEVATION  LATITUDE  LONGITUDE      DATE  PRCP  TAVG  \
# 0  GHCND:FIE00142080         51   60.3269    24.9603  19520101  0.31  37.0
# 1  GHCND:FIE00142080         51   60.3269    24.9603  19520102   NaN  35.0
# 2  GHCND:FIE00142080         51   60.3269    24.9603  19520103  0.14  33.0
# 3  GHCND:FIE00142080         51   60.3269    24.9603  19520104  0.05  29.0
# 4  GHCND:FIE00142080         51   60.3269    24.9603  19520105  0.06  27.0
#
#    TMAX  TMIN  DATE_STR YEAR_MONTH    TEMP_C
# 0  39.0  34.0  19520101     195201  2.777778
# 1  37.0  34.0  19520102     195201  1.666667
# 2  36.0   NaN  19520103     195201  0.555556
# 3  30.0  25.0  19520104     195201 -1.666667
# 4  30.0  25.0  19520105     195201 -2.777778

# %%
#create group based on year and month
grouped = data.groupby("YEAR_MONTH")

# %%
len(grouped)
# Out:
# 790

# %%
#calculate monthly avg temp
#create empty data frame for aggreate values
monthly_data = pd.DataFrame()

#column that we want to aggregate
mean_cols = ["TEMP_C"]

#Iterate over the groups
for key, group in grouped:
    
    #calculate mean
    mean_values = group[mean_cols].mean()
    
    #add the key(date info) into aggregate values
    mean_values["YEAR_MONTH"] = key
    
    #covert mean_values series to dataframeand make it row orientation
    row = mean_values.to_frame().transpose()
    
    #concatenate aggregated values into monthly dataframe
    monthly_data = pd.concat([monthly_data, row], ignore_index=True)
    
monthly_data
# Out:
#         TEMP_C YEAR_MONTH
# 0    -1.400966     195201
# 1         -4.0     195202
# 2   -10.106838     195203
# 3      4.22619     195204
# 4     7.037037     195205
# ..         ...        ...
# 785       13.5     201706
# 786  15.716846     201707
# 787  15.716846     201708
# 788  11.296296     201709
# 789   9.027778     201710
#
# [790 rows x 2 columns]

# %%
# This test print should print the length of variable monthly_data
print(len(monthly_data))
# Out:
# 790

# %%
# This test print should print the column names of monthly_data
print(monthly_data.columns.values)
# Out:
# ['TEMP_C' 'YEAR_MONTH']

# %%
# This test print should print the mean of temp_celsius
print(monthly_data['TEMP_C'].mean())
# Out:
# 5.097114347669993

# %%
# This test print should print the median of temp_celsius
print(round(monthly_data['TEMP_C'].median(), 2))
# Out:
# 4.73

# %% [markdown]
# ## PROBLEM 3
# Calculating temperature anomalies

# %% [markdown]
# ### Part 1
# Calculating the mean temperature for each month over the period from 1952 up to and including 1980

# %%
monthly_data["month"] = monthly_data["YEAR_MONTH"].str.slice(start=4, stop=6)
monthly_data
# Out:
#         TEMP_C YEAR_MONTH month
# 0    -1.400966     195201    01
# 1         -4.0     195202    02
# 2   -10.106838     195203    03
# 3      4.22619     195204    04
# 4     7.037037     195205    05
# ..         ...        ...   ...
# 785       13.5     201706    06
# 786  15.716846     201707    07
# 787  15.716846     201708    08
# 788  11.296296     201709    09
# 789   9.027778     201710    10
#
# [790 rows x 3 columns]

# %%
monthly_data["YEAR_MONTH"] = monthly_data["YEAR_MONTH"].astype(int)

# %%
#Calculating *the mean temperature for each month over the period from 1952 up to and including 1980* in a new DataFrame called reference_temps
#new dataframe with specified time period
reference_temps1 = pd.DataFrame(monthly_data.loc[(monthly_data["YEAR_MONTH"] >= 195201) & (monthly_data["YEAR_MONTH"] <= 198012)])

#changing column names
reference_temps1 = reference_temps1.rename(columns={"TEMP_C": 'ref_temps'})

#check data
reference_temps1
# Out:
#      ref_temps  YEAR_MONTH month
# 0    -1.400966      195201    01
# 1         -4.0      195202    02
# 2   -10.106838      195203    03
# 3      4.22619      195204    04
# 4     7.037037      195205    05
# ..         ...         ...   ...
# 343  14.784946      198008    08
# 344  10.814815      198009    09
# 345   5.232975      198010    10
# 346  -2.462963      198011    11
# 347   -2.97491      198012    12
#
# [348 rows x 3 columns]

# %%
#group months together
ref_temps = reference_temps1.groupby('month', as_index=False)['ref_temps'].mean()
ref_temps['month'] = ref_temps['month'].astype(int)
ref_temps
# Out:
#     month  ref_temps
# 0       1  -5.838761
# 1       2  -7.064088
# 2       3  -3.874213
# 3       4   2.370749
# 4       5   9.482356
# 5       6  14.661728
# 6       7  16.520986
# 7       8  15.045650
# 8       9   9.934222
# 9      10   4.952240
# 10     11   0.245195
# 11     12  -4.165641

# %%
ref_temps.dtypes
# Out:
# month          int32
# ref_temps    float64
# dtype: object

# %% [markdown]
# ### Part 2
# Calculating a temperature anomaly for every month

# %%
#join the two dataframes
monthly_data = monthly_data.merge(reference_temps1, on='month', how='outer')
monthly_data
# Out:
#        TEMP_C  YEAR_MONTH month  ref_temps
# 0   -1.400966      195201    01  -5.838761
# 1   -5.396825      195301    01  -5.838761
# 2    -7.07265      195401    01  -5.838761
# 3   -5.473251      195501    01  -5.838761
# 4   -8.133333      195601    01  -5.838761
# ..        ...         ...   ...        ...
# 785 -6.630824      201212    12  -4.165641
# 786  1.362007      201312    12  -4.165641
# 787 -1.146953      201412    12  -4.165641
# 788  2.204301      201512    12  -4.165641
# 789  -0.78853      201612    12  -4.165641
#
# [790 rows x 4 columns]

# %%
#calculate temp anomaly using ref_temps and temp c
monthly_data['diff'] = monthly_data['TEMP_C'] - monthly_data['ref_temps']
monthly_data
# Out:
#        TEMP_C  YEAR_MONTH month  ref_temps      diff
# 0   -1.400966      195201    01  -5.838761  4.437795
# 1   -5.396825      195301    01  -5.838761  0.441936
# 2    -7.07265      195401    01  -5.838761 -1.233888
# 3   -5.473251      195501    01  -5.838761   0.36551
# 4   -8.133333      195601    01  -5.838761 -2.294572
# ..        ...         ...   ...        ...       ...
# 785 -6.630824      201212    12  -4.165641 -2.465183
# 786  1.362007      201312    12  -4.165641  5.527648
# 787 -1.146953      201412    12  -4.165641  3.018688
# 788  2.204301      201512    12  -4.165641  6.369942
# 789  -0.78853      201612    12  -4.165641  3.377111
#
# [790 rows x 5 columns]

# %%
# Print out desriptive statistics for the relevant columns:
monthly_data[["TEMP_C", "diff", 'ref_temps']] = monthly_data[["TEMP_C", "diff", 'ref_temps']].astype(float)

# %%
monthly_data[["TEMP_C", "diff", 'ref_temps']].describe()
# Out:
#            TEMP_C        diff   ref_temps
# count  682.000000  682.000000  790.000000
# mean     5.097114    0.722724    4.371859
# std      8.483949    2.537855    8.284129
# min    -17.974910  -12.136149   -7.064088
# 25%     -1.685185   -0.820655   -3.874213
# 50%      4.726105    0.789118    4.952240
# 75%     12.870370    2.325922   13.479851
# max     22.329749    8.234723   16.520986

# %%
monthly_data.dtypes
# Out:
# TEMP_C        float64
# YEAR_MONTH      int32
# month          object
# ref_temps     float64
# diff          float64
# dtype: object

# %%
#monthly_data = monthly_data.set_index('YEAR_MONTH')
#monthly_data

# %%
# calculate which month had the largest temperature anomaly during the observed time period in comparison with the reference data
max_diff = monthly_data['diff'].max()
max_diff
# Out:
# 8.234722855723815

# %%
min_diff = monthly_data['diff'].min()
min_diff
# Out:
# -12.136149180361658

# %%
min_anomaly = monthly_data.loc[monthly_data['diff'] == min_diff, 'YEAR_MONTH']
min_anomaly
# Out:
# 35    198701
# Name: YEAR_MONTH, dtype: int32

# %%
max_anomaly = monthly_data.loc[monthly_data['diff'] == max_diff, 'YEAR_MONTH']
max_anomaly
# Out:
# 104    199002
# Name: YEAR_MONTH, dtype: int32

# %%
monthly_data.max(axis=0)
# Out:
# TEMP_C        22.329749
# YEAR_MONTH       201710
# month                12
# ref_temps     16.520986
# diff           8.234723
# dtype: object

# %%
min_anomaly
# Out:
# 35    198701
# Name: YEAR_MONTH, dtype: int32

# %% [markdown]
# # PROBLEM 4

# %% [markdown]
# 1. Start by downloading your own data (daily summaries for years 1959-2018 August) for Sodankyla Lokka (notice the place name should be without the letter ä), from the NOAA Climate Data Online Search. Make sure to select the starting day (and ending day) in the date selection panel after changing the year! After you have searched, click “Add to cart” for a selected station, then go to the cart. Select the Custom GHCN-Daily Text format for the resulting output file and hit continue.
#
# - From the Station Detail & Data Flag Options choose two of the following attributes: Station Name, Geographic Location. Notice: Do NOT include data flags because it makes the data difficult to read. Use Standard units.
# - Take also Precipitation and Temperature which are under a separate button below.
# - From the next page, add your own email address where the weather data will be sent after a short moment.
#
# 2. After you have downloaded the data. you should first,
# - Calculate the average temperature using columns TMAX and TMIN and insert those values into a new column called TAVG.
#
# 3. Next, you should use the approaches learned during this week and used in Problem 3 to answer / do the following:
#
# - Calculate the temperature anomalies in Sodankylä, i.e., the difference between reference_temps and the average temperature for each month (see Problem 3).
# - Calculate the monthly temperature differences between the Sodankylä and Helsinki stations
#     - How different are the summer temperatures (June, July, August) between Helsinki (used in Problems 1-3) and Sodankylä?
#     - What were the summer mean temperatures for both of these stations?
#     - What were the summer standard deviations for both of these stations?
# - Calculate the monthly differences in a DataFrame and save it (as CSV file) into your own Exercise repository for this week

# %%
#import pandas
import pandas as pd

#inport the data
fp = '3283151.txt'

data = pd.read_csv(fp,
                   skiprows=[1],
                   na_values=-9999,
                   delim_whitespace = True,
                   parse_dates = ['DATE']
                  )

data.head()
# Out:
#                             STATION STATION_NAME  ELEVATION LATITUDE  \
# GHCND:FIE00146538 SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#
#                              LONGITUDE       DATE  PRCP  TMAX  TMIN
# GHCND:FIE00146538 SODANKYLA    27.7503 1959-01-01  0.03   NaN   9.0
#                   SODANKYLA    27.7503 1959-01-02  0.00   NaN   6.0
#                   SODANKYLA    27.7503 1959-01-03  0.02   NaN  -9.0
#                   SODANKYLA    27.7503 1959-01-04  0.08   NaN  10.0
#                   SODANKYLA    27.7503 1959-01-05  0.09   NaN  13.0

# %%
#get TAVG using TMAX and TMIN
data['TAVG'] = (data['TMAX'] + data['TMIN']) / 2
data.head()
# Out:
#                             STATION STATION_NAME  ELEVATION LATITUDE  \
# GHCND:FIE00146538 SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#
#                              LONGITUDE       DATE  PRCP  TMAX  TMIN  TAVG
# GHCND:FIE00146538 SODANKYLA    27.7503 1959-01-01  0.03   NaN   9.0   NaN
#                   SODANKYLA    27.7503 1959-01-02  0.00   NaN   6.0   NaN
#                   SODANKYLA    27.7503 1959-01-03  0.02   NaN  -9.0   NaN
#                   SODANKYLA    27.7503 1959-01-04  0.08   NaN  10.0   NaN
#                   SODANKYLA    27.7503 1959-01-05  0.09   NaN  13.0   NaN

# %%
#Calculate the temperature anomalies in Sodankylä, i.e., the difference between reference_temps and the average temperature for each month
#create year and month column
data['YR_MNT'] = data['DATE'].dt.to_period('M')
data.head()
# Out:
#                             STATION STATION_NAME  ELEVATION LATITUDE  \
# GHCND:FIE00146538 SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#
#                              LONGITUDE       DATE  PRCP  TMAX  TMIN  TAVG  \
# GHCND:FIE00146538 SODANKYLA    27.7503 1959-01-01  0.03   NaN   9.0   NaN
#                   SODANKYLA    27.7503 1959-01-02  0.00   NaN   6.0   NaN
#                   SODANKYLA    27.7503 1959-01-03  0.02   NaN  -9.0   NaN
#                   SODANKYLA    27.7503 1959-01-04  0.08   NaN  10.0   NaN
#                   SODANKYLA    27.7503 1959-01-05  0.09   NaN  13.0   NaN
#
#                               YR_MNT
# GHCND:FIE00146538 SODANKYLA  1959-01
# ...

# %%
data['TEMP_C'] = (data['TAVG'] - 32) / 1.8
data.head()
# Out:
#                             STATION STATION_NAME  ELEVATION LATITUDE  \
# GHCND:FIE00146538 SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#                   SODANKYLA   LOKKA           FI        240  67.8206
#
#                              LONGITUDE       DATE  PRCP  TMAX  TMIN  TAVG  \
# GHCND:FIE00146538 SODANKYLA    27.7503 1959-01-01  0.03   NaN   9.0   NaN
#                   SODANKYLA    27.7503 1959-01-02  0.00   NaN   6.0   NaN
#                   SODANKYLA    27.7503 1959-01-03  0.02   NaN  -9.0   NaN
#                   SODANKYLA    27.7503 1959-01-04  0.08   NaN  10.0   NaN
#                   SODANKYLA    27.7503 1959-01-05  0.09   NaN  13.0   NaN
#
#                               YR_MNT  TEMP_C
# GHCND:FIE00146538 SODANKYLA  1959-01     NaN
# ...

# %%
#group by year_month and get mean
monthly_data_soda = data.groupby('YR_MNT', as_index=False)['TEMP_C'].mean()
monthly_data_soda = pd.DataFrame(monthly_data_soda)
monthly_data_soda
# Out:
#       YR_MNT     TEMP_C
# 0    1959-01        NaN
# 1    1959-02        NaN
# 2    1959-03        NaN
# 3    1959-04        NaN
# 4    1959-05   5.259857
# ..       ...        ...
# 682  2018-04  -1.814815
# 683  2018-05   8.234767
# 684  2018-06   9.851852
# 685  2018-07  17.706093
# 686  2018-08  12.508961
#
# [687 rows x 2 columns]

# %%
#get month column
monthly_data_soda['MONTH'] = monthly_data_soda['YR_MNT'].dt.month
monthly_data_soda
# Out:
#       YR_MNT     TEMP_C  MONTH
# 0    1959-01        NaN      1
# 1    1959-02        NaN      2
# 2    1959-03        NaN      3
# 3    1959-04        NaN      4
# 4    1959-05   5.259857      5
# ..       ...        ...    ...
# 682  2018-04  -1.814815      4
# 683  2018-05   8.234767      5
# 684  2018-06   9.851852      6
# 685  2018-07  17.706093      7
# 686  2018-08  12.508961      8
#
# [687 rows x 3 columns]

# %%
#Calculating *the mean temperature for each month over the period from 1952 up to and including 1980* in a new DataFrame called reference_temps
refrence_temps = monthly_data_soda.groupby('MONTH', as_index=False)['TEMP_C'].mean()
refrence_temps = pd.DataFrame(refrence_temps)
refrence_temps.rename(columns={'TEMP_C':'ref_temps'}, inplace=True)
refrence_temps
# Out:
#     MONTH  ref_temps
# 0       1 -14.682860
# 1       2 -14.134748
# 2       3  -9.550585
# 3       4  -3.118221
# 4       5   3.885682
# 5       6  10.388250
# 6       7  13.543428
# 7       8  10.975930
# 8       9   5.746589
# 9      10  -0.856914
# 10     11  -7.617122
# 11     12 -12.353487

# %%
refrence_temps.dtypes
# Out:
# MONTH          int64
# ref_temps    float64
# dtype: object

# %%
#merge the dataFrames
monthly_data_soda = monthly_data_soda.merge(refrence_temps, on='MONTH', how='outer')
monthly_data_soda
# Out:
#       YR_MNT     TEMP_C  MONTH  ref_temps
# 0    1959-01        NaN      1 -14.682860
# 1    1960-01 -19.121864      1 -14.682860
# 2    1961-01 -11.182796      1 -14.682860
# 3    1962-01 -15.421147      1 -14.682860
# 4    1963-01 -18.145161      1 -14.682860
# ..       ...        ...    ...        ...
# 682  2013-12  -9.749104     12 -12.353487
# 683  2014-12  -9.587814     12 -12.353487
# 684  2015-12 -10.564516     12 -12.353487
# 685  2016-12 -10.367384     12 -12.353487
# 686  2017-12 -10.896057     12 -12.353487
#
# [687 rows x 4 columns]

# %%
#find difference between monthly data amd refrence
monthly_data_soda['diff'] = monthly_data_soda['TEMP_C'] - monthly_data_soda['ref_temps']
monthly_data_soda
# Out:
#       YR_MNT     TEMP_C  MONTH  ref_temps      diff
# 0    1959-01        NaN      1 -14.682860       NaN
# 1    1960-01 -19.121864      1 -14.682860 -4.439004
# 2    1961-01 -11.182796      1 -14.682860  3.500064
# 3    1962-01 -15.421147      1 -14.682860 -0.738287
# 4    1963-01 -18.145161      1 -14.682860 -3.462302
# ..       ...        ...    ...        ...       ...
# 682  2013-12  -9.749104     12 -12.353487  2.604383
# 683  2014-12  -9.587814     12 -12.353487  2.765673
# 684  2015-12 -10.564516     12 -12.353487  1.788971
# 685  2016-12 -10.367384     12 -12.353487  1.986103
# 686  2017-12 -10.896057     12 -12.353487  1.457429
#
# [687 rows x 5 columns]

# %%
monthly_data_soda.describe().round(2)
# Out:
#        TEMP_C   MONTH  ref_temps    diff
# count  683.00  687.00     687.00  683.00
# mean    -1.37    6.50      -1.42    0.00
# std     10.28    3.45       9.86    2.89
# min    -24.54    1.00     -14.68  -10.41
# 25%    -10.20    4.00      -9.55   -1.55
# 50%     -1.58    7.00      -0.86    0.09
# 75%      8.28    9.00      10.39    1.64
# max     17.71   12.00      13.54   10.08

# %%
#get months of summer temp
summer_temps_soda = refrence_temps.loc[(refrence_temps['MONTH'] >= 5) & (refrence_temps['MONTH'] < 8)]
summer_temps_soda.rename(columns={'MONTH':'month'}, inplace=True)
summer_temps_soda
# Out:
# C:\Users\Joe\AppData\Local\Temp\ipykernel_23580\3257407748.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer_temps_soda.rename(columns={'MONTH':'month'}, inplace=True)
#    month  ref_temps
# 4      5   3.885682
# 5      6  10.388250
# 6      7  13.543428

# %%
summer_temps_soda.dtypes
# Out:
# month          int64
# ref_temps    float64
# dtype: object

# %%
#get average summer temps
summer_temps_soda['ref_temps'].mean()
# Out:
# 9.272453382973355

# %%
ref_temps.dtypes
# Out:
# month          int32
# ref_temps    float64
# dtype: object

# %%
#get summer temps for helsinki
summer_temps_helsi = ref_temps.loc[(ref_temps['month'] >= 5) & (ref_temps['month'] < 8)]
summer_temps_helsi
# Out:
#    month  ref_temps
# 4      5   9.482356
# 5      6  14.661728
# 6      7  16.520986

# %%
summer_temps_helsi['month'].astype(int)
# Out:
# 5    6
# 6    7
# 7    8
# Name: month, dtype: int32

# %%
summer_temps_helsi.dtypes
# Out:
# month         object
# ref_temps    float64
# dtype: object

# %%
summer_temps_helsi['ref_temps'].mean()
# Out:
# 15.409454453686662

# %%
summer_temps_comb = summer_temps_helsi.merge(summer_temps_soda, on='month', how='outer')
summer_temps_comb
# Out:
#    month  ref_temps_x  ref_temps_y
# 0      5     9.482356     3.885682
# 1      6    14.661728    10.388250
# 2      7    16.520986    13.543428

# %%
#temp difference between the stations
summer_temps_helsi['ref_temps'].mean() - summer_temps_soda['ref_temps'].mean()
# Out:
# 4.282569886103879

# %%
#standard deviation of both stations
print(summer_temps_helsi['ref_temps'].std())
print(summer_temps_soda['ref_temps'].std())
# Out:
# 3.6474887468332993
# 4.9246082324931075
